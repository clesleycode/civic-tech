# %%
from nytimesarticle import articleAPI
api = articleAPI('2205589d813c42acb5d34c5b729ce392')

# %%
articles = api.search(q = 'Civic Tech', begin_date = 20111231)

# %%
print(articles)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.', 'response': {'docs': [], 'meta': {'hits': 0, 'offset': 0, 'time': 9}}}

# %%
# Out:
# status
# copyright
# response

# %%
import requests

r = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=propublica&begin_date=20161001&api-key=2205589d813c42acb5d34c5b729ce392")

# %%
data = r.json()

# %%
data
# Out:
# {'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'_id': '5a5fae0a7c459f29e79b478e',
#     'blog': {},
#     'byline': {'organization': None,
#      'original': 'By MEGAN ROSE',
#      'person': [{'firstname': 'Megan',
#        'lastname': 'ROSE',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Op-Ed Contributor',
#      'kicker': 'Op-Ed Contributor',
#      'main': 'Innocent but Still Guilty',
#      'name': None,
#      'print_headline': 'Innocent but Still Guilty',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'False Arrests, Convictions and Imprisonments'},
#      {'major': 'N', 'name': 'persons', 'rank': 2, 'value': 'Steese, Fred'},
# ...

# %%
data['response']
# Out:
# {'docs': [{'_id': '5a5fae0a7c459f29e79b478e',
#    'blog': {},
#    'byline': {'organization': None,
#     'original': 'By MEGAN ROSE',
#     'person': [{'firstname': 'Megan',
#       'lastname': 'ROSE',
#       'middlename': None,
#       'organization': '',
#       'qualifier': None,
#       'rank': 1,
#       'role': 'reported',
#       'title': None}]},
#    'document_type': 'article',
#    'headline': {'content_kicker': 'Op-Ed Contributor',
#     'kicker': 'Op-Ed Contributor',
#     'main': 'Innocent but Still Guilty',
#     'name': None,
#     'print_headline': 'Innocent but Still Guilty',
#     'seo': None,
#     'sub': None},
#    'keywords': [{'major': 'N',
#      'name': 'subject',
#      'rank': 1,
#      'value': 'False Arrests, Convictions and Imprisonments'},
#     {'major': 'N', 'name': 'persons', 'rank': 2, 'value': 'Steese, Fred'},
#     {'major': 'N', 'name': 'glocations', 'rank': 3, 'value': 'Nevada'},
# ...

# %%
for i in data['response']['docs']: 
    print(i['headline'])
# Out:
# {'main': 'Innocent but Still Guilty', 'kicker': 'Op-Ed Contributor', 'content_kicker': 'Op-Ed Contributor', 'print_headline': 'Innocent but Still Guilty', 'name': None, 'seo': None, 'sub': None}
# {'main': 'Can Software Predict Crime? Maybe So, but No Better Than a Human', 'kicker': None, 'content_kicker': None, 'print_headline': 'This Software May Predict Crime, or You Can Ask the Average Human', 'name': None, 'seo': None, 'sub': None}
# {'main': 'Facebook Job Ads Raise Concerns About Age Discrimination', 'kicker': None, 'content_kicker': None, 'print_headline': 'Targeted Job Ads on Facebook Prompt Concerns About Age Bias', 'name': None, 'seo': None, 'sub': None}
# {'main': 'E.P.A. Officials, Disheartened by Agency’s Direction, Are Leaving in Droves', 'kicker': None, 'content_kicker': None, 'print_headline': 'E.P.A. Officials, Disheartened by Agency’s Direction, Leave in Droves', 'name': None, 'seo': None, 'sub': None}
# ...

# %%
from twitter import *

t = Twitter(
    auth=OAuth('54091737-Te65diCAQ7QaQHI8lV86YQ8pqbvm3cK8zM4Scc5IR', 'Ytf6abfsuAj9kYqzYm6eA8JLz1okaygGXOpJGNjyopUCE', 'cHTThoqYt610bCrXxR1gVv6qr', 'NLmX22gq1pEuFW1J2RlFyErc55pEJ2TpMU3nY47Leec0NVLnhf'))

# %%
civic_tech = t.search.tweets(q="#civictech")

# %%
for i in civic_tech['search_metadata']: 
    print(i)
# Out:
# statuses
# search_metadata

# %%
for i in civic_tech['statuses']: 
    print(i)
# Out:
# {'created_at': 'Sun Feb 18 04:20:43 +0000 2018', 'id': 965078601161936896, 'id_str': '965078601161936896', 'text': 'RT @Labcities: How #CivicTech Can Address Urban Inequality https://t.co/FY2mZrSsTl', 'truncated': False, 'entities': {'hashtags': [{'text': 'CivicTech', 'indices': [19, 29]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Labcities', 'name': 'LABCITIES', 'id': 2355121538, 'id_str': '2355121538', 'indices': [3, 13]}], 'urls': [{'url': 'https://t.co/FY2mZrSsTl', 'expanded_url': 'http://www.labcities.com/civic-tech-can-address-urban-inequality/', 'display_url': 'labcities.com/civic-tech-can…', 'indices': [59, 82]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3316389358, 'id_str'
# ...
